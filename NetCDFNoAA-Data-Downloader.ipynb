# %%
import numpy as np
import netCDF4 as nc
import xarray as xr

# %%
ls RemoteData/RemoteSensingData/NOAA-DATA/ -lahr

# %%
import os
import shutil
import requests

def download_data(url, temp_dir, destination_dir):
    # Create temporary directory if it doesn't exist
    os.makedirs(temp_dir, exist_ok=True)

    # Extract filename from the URL
    filename = url.split("/")[-1]

    # Download the file to the temporary directory
    temp_file = os.path.join(temp_dir, filename)
    response = requests.get(url, stream=True)
    with open(temp_file, "wb") as f:
        shutil.copyfileobj(response.raw, f)
    del response

    # Move the file to the destination directory
    destination_file = os.path.join(destination_dir, filename)
    shutil.move(temp_file, destination_file)

    print(f"File downloaded and moved to: {destination_file}")

# Set the URL, temporary directory, and destination directory
url = "https://www.ncei.noaa.gov/data/geostationary-ir-channel-brightness-temperature-gridsat-b1/access/2019/GRIDSAT-B1.2019.01.22.15.v02r01.nc"
temp_dir = "tmp"
destination_dir = "RemoteData/RemoteSensingData/NOAA-DATA"

# Call the function to download the data
download_data(url, temp_dir, destination_dir)

# %%
response = requests.get("https://www.ncei.noaa.gov/data/geostationary-ir-channel-brightness-temperature-gridsat-b1/access/2019")
response.text.split("\n")

# %%
import os
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup

def explore_and_download_data(base_url, start_year, end_year, temp_dir, destination_dir):
    # Create temporary directory if it doesn't exist
    os.makedirs(temp_dir, exist_ok=True)

    # Iterate over the years
    for year in range(start_year, end_year + 1):
        # Generate the URL for the specific year
        year_url = urljoin(base_url, str(year))

        # Create the destination directory for the specific year
        year_destination_dir = os.path.join(destination_dir, str(year))
        os.makedirs(year_destination_dir, exist_ok=True)

        # Get the HTML content of the year URL
        response = requests.get(year_url)
        soup = BeautifulSoup(response.content, "html.parser")

        # Find all the links on the page
        links = soup.find_all("a")

        # Iterate over the links and download the files
        for link in links:
            file_name = link.get("href")
            if file_name.endswith(".nc"):
                file_url = urljoin(year_url, file_name)
                temp_file = os.path.join(temp_dir, file_name)
                destination_file = os.path.join(year_destination_dir, file_name)

                # Download the file to the temporary directory
                response = requests.get(file_url, stream=True)
                with open(temp_file, "wb") as f:
                    response.raw.decode_content = True
                    shutil.copyfileobj(response.raw, f)
                del response

                # Move the file to the destination directory
                shutil.move(temp_file, destination_file)

                print(f"File downloaded and moved to: {destination_file}")

# Set the base URL, start year, end year, temporary directory, and destination directory
base_url = "https://www.ncei.noaa.gov/data/geostationary-ir-channel-brightness-temperature-gridsat-b1/access/"
start_year = 2019
end_year = 2023
temp_dir = "/tmp"
destination_dir = "RemoteData/RemoteSensingData/NOAA-DATA"

# Call the function to explore and download the data
explore_and_download_data(base_url, start_year, end_year, temp_dir, destination_dir)
# Out:
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.25.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07.26.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.07
06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.08.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.08.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.08.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.08.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.08.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.09.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.10.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.11.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.12.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.13.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.14.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.15.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.16.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.17.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2020/GRIDSAT-B1.2020.09.18.00.v02r01.nc
# ...
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.13.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.13.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.14.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.15.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.16.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.17.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.18.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.19.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.20.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.21.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.22.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.23.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.24.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.25.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.26.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.27.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.28.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.29.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.30.21.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.00.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.03.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.06.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.09.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.12.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.15.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.18.v02r01.nc
# File downloaded and moved to: RemoteData/RemoteSensingData/NOAA-DATA/2023/GRIDSAT-B1.2023.03.31.21.v02r01.nc

# %%
import os
import xarray as xr
import pandas as pd

# Set the base directory where the files are stored
base_dir = "RemoteData/RemoteSensingData/NOAA-DATA"

# Set the start and end years
start_year = 2019
end_year = 2023

# Create an empty list to store the data from each year
dfs = []

# Iterate over the years
for year in range(start_year, end_year + 1):
    # Set the file path for the specific year
    file_path = os.path.join(base_dir, str(year), f"GRIDSAT-B1.{year}.nc")

    # Load the NetCDF data using xarray
    data = xr.open_dataset(file_path)

    # Convert the data to a pandas DataFrame
    df = data.to_dataframe()

    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate the DataFrames from each year into a single DataFrame
combined_df = pd.concat(dfs)

# Preview the combined DataFrame
print(combined_df.head())

# %%
ls /thesis/Thesis_Work/Data/RemoteData/RemoteSensingData/NOAA-DATA/
